# %% [markdown]
# # 03. SOTA: DA-ADB
#
# Distance-Aware Adaptive Decision Boundary (Zhang et al., 2021).
# Верхняя граница качества для OOS-детекции.
#
# ## Содержание
# 1. Настройка и обучение
# 2. Оценка на тест-сплите
# 3. Анализ ошибок

# %%
# TODO: imports

# %% [markdown]
# ## 1. Настройка и обучение

# %%
# TODO

# %% [markdown]
# ## 2. Оценка на тест-сплите

# %%
# TODO

# %% [markdown]
# ## 3. Анализ ошибок

# %%
# TODO
