# %% [markdown]
# # 06. Hypothesis Testing
#
# Проверка гипотез для улучшения OOS-детекции.
#
# ## Содержание
# 1. HYP-001: Per-intent threshold calibration
# 2. Анализ результатов
# 3. Выводы

# %%
# TODO: imports

# %% [markdown]
# ## 1. HYP-001: Per-intent threshold calibration
#
# **Гипотеза:** Калибровка порога OOS-детекции отдельно для каждого
# intent-кластера улучшает Recall@FPR на hard OOS без потери precision.
#
# **Мотивация:** Разные intent-кластеры имеют разную плотность в
# embedding-пространстве — глобальный порог неоптимален.

# %%
# TODO

# %% [markdown]
# ## 2. Анализ результатов

# %%
# TODO

# %% [markdown]
# ## 3. Выводы

# %%
# TODO
